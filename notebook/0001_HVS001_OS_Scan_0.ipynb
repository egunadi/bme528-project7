# %%
import sys
sys.path.append('../code/python')

from OCT_Dewarp_BL import OCT_Dewarp_BL
from OCT_OuterCornea import OCT_OuterCornea
from OCT_InnerCornea import OCT_InnerCornea
from OuterDewarp import OuterDewarp
from InnerDewarp import InnerDewarp

# %%
OCT_Dewarp_BL('../images/original/0001_HVS001_OS_Scan_0.png')
# Out:
# loading vars
# loading image
# converting to im2uint8
# reshaping image
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 OCT_Dewarp_BL('../images/original/0001_HVS001_OS_Scan_0.png')
#
# File ~/Git/bme528-project7/notebook/../code/python/OCT_Dewarp_BL.py:75, in OCT_Dewarp_BL(uncorrectedimg, debug)
#      70 originalgrayrsz = cv2.resize(originalgray,(y_dimension,x_dimension))
#      72 # originalgrayrsz is a modified version of originalgray
#      73
#      74 # -------------- Call function "OCT_OuterCornea" to detect outer cornea boundary:
# ---> 75 Extcornea = OCT_OuterCornea(originalgrayrsz)
#      77 # -------------------------------------------------------------------------- Get Internal Cornea Boundary:
#      78 # -------------- Call function "OCT_InnerCornea" to detect inner cornea boundary:
#      79 Intcornea = OCT_InnerCornea(Extcornea)
#
# NameError: name 'OCT_OuterCornea' is not defined
